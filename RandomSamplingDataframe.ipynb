# %%
import pandas as pd
import numpy as np
Location = "datasets/gradedata.csv"
df = pd.read_csv(Location)
df.tail()
df.take(np.random.permutation(len(df))[:500])
# Out:
#         fname     lname  gender  age  exercise  hours  grade  \
# 1758     Omar   Pittman    male   14         5      2   66.6
# 1965  Lavinia      Carr  female   16         2      4   62.2
# 645    Stella    Taylor  female   19         3      3   65.5
# 1678   Nevada  Mcdonald  female   19         2     11   81.3
# 36       Ivor    Arnold    male   19         4     20  100.0
# ...       ...       ...     ...  ...       ...    ...    ...
# 179     Slade   Padilla    male   17         5     16   93.1
# 347     Jayme  Santiago  female   16         3      6   77.1
# 1741  Griffin    French    male   19         2     11   73.2
# 1030   Steven     Frank    male   18         2     10   85.7
# 1228   Chaney   Edwards    male   14         2      9   75.8
#
#                                             address
# 1758        281 Tower Street, Saint Johns, FL 32259
# 1965    993 Rockaway Road, Fleming Island, FL 32003
# 645   7372 Marlborough Ave., Phoenixville, PA 19460
# ...
